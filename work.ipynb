# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn

df = pd.read_parquet(r'Data\hackathonlicence\consumption.parquet', engine='fastparquet')

print(df) #апп
print(df.shape)
# Out:
#            date  territory_id              category  value
# 0       2023-01             1        Продовольствие   7692
# 1       2023-01             1              Здоровье   1271
# 2       2023-01             1          Маркетплейсы   2505
# 3       2023-01             1  Общественное питание   1142
# 5       2023-01             1             Транспорт   1718
# ...         ...           ...                   ...    ...
# 353641  2024-12          3101              Здоровье   1483
# 353642  2024-12          3101          Маркетплейсы   6854
# 353643  2024-12          3101  Общественное питание    525
# 353645  2024-12          3101             Транспорт   1209
# 353646  2024-12          3101         Все категории  30701
#
# [303126 rows x 4 columns]
# (303126, 4)

# %%
print("=== ОСНОВНАЯ ИНФОРМАЦИЯ ===")
print(f"Размер данных: {df.shape}")
print(f"Столбцы: {df.columns.tolist()}")
print("\nТипы данных:")
print(df.dtypes)

print("\n=== ПЕРВЫЕ СТРОКИ ===")
print(df.head(10))

print("\n=== ИНФОРМАЦИЯ О ДАННЫХ ===")
print(df.info())

print("\n=== УНИКАЛЬНЫЕ ЗНАЧЕНИЯ ===")
print("По столбцам:")
print(df.nunique())

print("\n=== ПРОВЕРКА ПРОПУСКОВ ===")
print(df.isnull().sum())

print("\n=== КОЛИЧЕСТВО ЗАПИСЕЙ ДЛЯ TERRITORY_ID == 1 ===")
count_1 = len(df[df['territory_id'] == 1])
print(f"Количество строк с territory_id = 1: {count_1}")

print("\n=== КОЛИЧЕСТВО ЗАПИСЕЙ ДЛЯ TERRITORY_ID == 3101 ===")
count_1 = len(df[df['territory_id'] == 3101])
print(f"Количество строк с territory_id = 1: {count_1}")

print("\n=== МАКСИМАЛЬНОЕ ЗНАЧЕНИЕ TERRITORY_ID")
max_territory = df['territory_id'].max()
print(max_territory)
# Out:
# === ОСНОВНАЯ ИНФОРМАЦИЯ ===
# Размер данных: (303126, 4)
# Столбцы: ['date', 'territory_id', 'category', 'value']
#
# Типы данных:
# date            object
# territory_id     int16
# category        object
# value            int32
# dtype: object
#
# === ПЕРВЫЕ СТРОКИ ===
#        date  territory_id              category  value
# 0   2023-01             1        Продовольствие   7692
# 1   2023-01             1              Здоровье   1271
# 2   2023-01             1          Маркетплейсы   2505
# 3   2023-01             1  Общественное питание   1142
# 5   2023-01             1             Транспорт   1718
# 6   2023-01             1         Все категории  21580
# 7   2023-01             2        Продовольствие   6395
# 8   2023-01             2              Здоровье   1257
# 9   2023-01             2          Маркетплейсы   2192
# 10  2023-01             2  Общественное питание   1167
#
# === ИНФОРМАЦИЯ О ДАННЫХ ===
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
df = pd.read_parquet(r'Data\hackathonlicence\market_access.parquet', engine='fastparquet')


print("=== ОСНОВНАЯ ИНФОРМАЦИЯ ===")
print(f"Размер данных: {df.shape}")
print(f"Столбцы: {df.columns.tolist()}")
print("\nТипы данных:")
print(df.dtypes)

print("\n=== ПЕРВЫЕ СТРОКИ ===")
print(df.head(10))

print("\n=== ИНФОРМАЦИЯ О ДАННЫХ ===")
print(df.info())

print("\n=== УНИКАЛЬНЫЕ ЗНАЧЕНИЯ ===")
print("По столбцам:")
print(df.nunique())

print("\n=== ПРОВЕРКА ПРОПУСКОВ ===")
print(df.isnull().sum())

print("\n=== МАКСИМАЛЬНОЕ ЗНАЧЕНИЕ TERRITORY_ID")
max_territory = df['territory_id'].max()
print(max_territory)
# Out:
# === ОСНОВНАЯ ИНФОРМАЦИЯ ===
# Размер данных: (2571, 2)
# Столбцы: ['territory_id', 'market_access']
#
# Типы данных:
# territory_id       int32
# market_access    float64
# dtype: object
#
# === ПЕРВЫЕ СТРОКИ ===
#    territory_id  market_access
# 0             1          309.6
# 1             2          322.8
# 2             3          315.2
# 3             4          315.5
# 4             5          320.2
# 5             6          308.1
# 6             7          324.7
# 7             8          317.4
# 8             9          314.3
# 9            10          213.5
#
# === ИНФОРМАЦИЯ О ДАННЫХ ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2571 entries, 0 to 2570
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   territory_id   2571 non-null   int32
#  1   market_access  2571 non-null   float64
# dtypes: float64(1), int32(1)
# memory usage: 30.3 KB
# None
#
# === УНИКАЛЬНЫЕ ЗНАЧЕНИЯ ===
# ...

# %%
df = pd.read_parquet(r'Data\Rosstat\rosstat\rosstat\2_bdmo_population.parquet', engine='fastparquet')

print("=== ОСНОВНАЯ ИНФОРМАЦИЯ ===")
print(f"Размер данных: {df.shape}")
print(f"Столбцы: {df.columns.tolist()}")
print("\nТипы данных:")
print(df.dtypes)

print("\n=== ПЕРВЫЕ СТРОКИ ===")
print(df.head(10))

print("\n=== ИНФОРМАЦИЯ О ДАННЫХ ===")
print(df.info())

print("\n=== УНИКАЛЬНЫЕ ЗНАЧЕНИЯ ===")
print("По столбцам:")
print(df.nunique())

print("\n=== ПРОВЕРКА ПРОПУСКОВ ===")
print(df.isnull().sum())

print("\n=== КОЛИЧЕСТВО ЗАПИСЕЙ ДЛЯ TERRITORY_ID == 1 ===")
count_1 = len(df[df['territory_id'] == 1])
print(f"Количество строк с territory_id = 1: {count_1}")

print("\n=== КОЛИЧЕСТВО ЗАПИСЕЙ ДЛЯ TERRITORY_ID == 3101 ===")
count_1 = len(df[df['territory_id'] == 3101])
print(f"Количество строк с territory_id = 1: {count_1}")

print("\n=== МАКСИМАЛЬНОЕ ЗНАЧЕНИЕ TERRITORY_ID")
max_territory = df['territory_id'].max()
print(max_territory)
# Out:
# === ОСНОВНАЯ ИНФОРМАЦИЯ ===
# Размер данных: (700215, 6)
# Столбцы: ['territory_id', 'year', 'period', 'age', 'gender', 'value']
#
# Типы данных:
# territory_id      int64
# year              int64
# period           object
# age              object
# gender           object
# value           float64
# dtype: object
#
# === ПЕРВЫЕ СТРОКИ ===
#    territory_id  year period age   gender  value
# 0          1402  2023    год   0  Женщины  288.0
# 1          1402  2023    год   0  Мужчины  301.0
# 2          1402  2023    год   1  Женщины  277.0
# 3          1402  2023    год   1  Мужчины  316.0
# 4          1402  2023    год  10  Женщины  414.0
# 5          1402  2023    год  10  Мужчины  429.0
# 6          1402  2023    год  11  Женщины  395.0
# 7          1402  2023    год  11  Мужчины  431.0
# 8          1402  2023    год  12  Женщины  426.0
# 9          1402  2023    год  12  Мужчины  460.0
#
# === ИНФОРМАЦИЯ О ДАННЫХ ===
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
migration = pd.read_parquet(r'Data\Rosstat\rosstat\rosstat\3_bdmo_migration.parquet', engine='fastparquet')


print("=== ОСНОВНАЯ ИНФОРМАЦИЯ ===")
print(f"Размер данных: {migration.shape}")
print(f"Столбцы: {migration.columns.tolist()}")
print("\nТипы данных:")
print(migration.dtypes)

print("\n=== ПЕРВЫЕ СТРОКИ ===")
print(migration.head(10))

print("\n=== ИНФОРМАЦИЯ О ДАННЫХ ===")
print(migration.info())

print("\n=== УНИКАЛЬНЫЕ ЗНАЧЕНИЯ ===")
print("По столбцам:")
print(migration.nunique())

print("\n=== ПРОВЕРКА ПРОПУСКОВ ===")
print(migration.isnull().sum())

print("\n=== КОЛИЧЕСТВО ЗАПИСЕЙ ДЛЯ TERRITORY_ID == 1 ===")
count_1 = len(migration[migration['territory_id'] == 1])
print(f"Количество строк с territory_id = 1: {count_1}")

print("\n=== КОЛИЧЕСТВО ЗАПИСЕЙ ДЛЯ TERRITORY_ID == 3101 ===")
count_1 = len(migration[migration['territory_id'] == 3101])
print(f"Количество строк с territory_id = 1: {count_1}")

print("\n=== МАКСИМАЛЬНОЕ ЗНАЧЕНИЕ TERRITORY_ID")
max_territory = migration['territory_id'].max()
print(max_territory)
# Out:
# === ОСНОВНАЯ ИНФОРМАЦИЯ ===
# Размер данных: (106224, 6)
# Столбцы: ['territory_id', 'year', 'period', 'age', 'gender', 'value']
#
# Типы данных:
# territory_id      int64
# year              int64
# period           object
# age              object
# gender           object
# value           float64
# dtype: object
#
# === ПЕРВЫЕ СТРОКИ ===
#    territory_id  year period    age   gender  value
# 0          2335  2023    год  75-79  Женщины    5.0
# 1          2335  2023    год  75-79  Мужчины    NaN
# 2          2335  2023    год  55-59  Женщины   -4.0
# 3          2335  2023    год  55-59  Мужчины   -4.0
# 4          2335  2023    год  15-19  Женщины  -11.0
# 5          2335  2023    год  15-19  Мужчины  -17.0
# 6          2335  2023    год  90-94  Женщины    1.0
# 7          2335  2023    год  90-94  Мужчины    NaN
# 8          2335  2023    год  50-54  Женщины   18.0
# 9          2335  2023    год  50-54  Мужчины   15.0
#
# === ИНФОРМАЦИЯ О ДАННЫХ ===
# ...

# %%
df = pd.read_csv(r'Data\territory_id_pora.csv', encoding='windows-1251', sep=';')

arctic_migration = migration.loc[migration.territory_id.isin(df.territory_id)]
arctic_migration = arctic_migration.merge(df[['territory_id', 'settlement_name']], 
                                          on='territory_id', 
                                          how='left')

пиндуши = arctic_migration.loc[arctic_migration.territory_id == 917]
print(пиндуши)
# Out:
#     territory_id  year period    age   gender  value  \
# 0            917  2023    год  75-79  Женщины    2.0
# 1            917  2023    год  75-79  Мужчины   -1.0
# 2            917  2023    год  55-59  Женщины   -6.0
# 3            917  2023    год  55-59  Мужчины    3.0
# 4            917  2023    год  15-19  Женщины  -24.0
# 5            917  2023    год  15-19  Мужчины   -5.0
# 6            917  2023    год  90-94  Женщины    1.0
# 7            917  2023    год  90-94  Мужчины    NaN
# 8            917  2023    год  50-54  Женщины   -3.0
# 9            917  2023    год  50-54  Мужчины    4.0
# 10           917  2023    год  35-39  Женщины   37.0
# 11           917  2023    год  35-39  Мужчины   39.0
# 12           917  2023    год  40-44  Женщины   20.0
# 13           917  2023    год  40-44  Мужчины   15.0
# 14           917  2023    год    0-4  Женщины  -10.0
# 15           917  2023    год    0-4  Мужчины  -12.0
# 16           917  2023    год    5-9  Женщины  -14.0
# ...

# %%
consumption = pd.read_parquet('Data/hackathonlicence/consumption.parquet')

arctic_consumption = consumption.loc[consumption.territory_id.isin(df.territory_id)]
arctic_consumption = arctic_consumption.merge(df[['territory_id', 'settlement_name']], 
                                          on='territory_id',
                                          how='left')
print(arctic_consumption.head(20))
# Out:
#        date  territory_id              category  value settlement_name
# 0   2023-01           209        Продовольствие  14130    пгт Калевала
# 1   2023-01           209              Здоровье   1231    пгт Калевала
# 2   2023-01           209          Маркетплейсы   3513    пгт Калевала
# 3   2023-01           209  Общественное питание    318    пгт Калевала
# 4   2023-01           209             Транспорт   1879    пгт Калевала
# 5   2023-01           209         Все категории  27080    пгт Калевала
# 6   2023-01           213        Продовольствие  13474       пгт Лоухи
# 7   2023-01           213              Здоровье   1179       пгт Лоухи
# 8   2023-01           213          Маркетплейсы   3933       пгт Лоухи
# 9   2023-01           213  Общественное питание    443       пгт Лоухи
# 10  2023-01           213             Транспорт   1278       пгт Лоухи
# 11  2023-01           213         Все категории  28297       пгт Лоухи
# ...
